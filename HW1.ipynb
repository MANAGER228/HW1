# %%
#Задание 1

# %%
import requests
import json
from pprint import pprint

# %%
url = 'https://api.github.com'
user_name = 'MANAGER228'

# %%
req = requests.get(f'{url}/users/{user_name}/repos')

# %%
data = req.json()

# %%
pprint(data)
# Out:
# [{'archive_url': 'https://api.github.com/repos/MANAGER228/HMW3/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/MANAGER228/HMW3/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/MANAGER228/HMW3/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/MANAGER228/HMW3/branches{/branch}',
#   'clone_url': 'https://github.com/MANAGER228/HMW3.git',
#   'collaborators_url': 'https://api.github.com/repos/MANAGER228/HMW3/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/MANAGER228/HMW3/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/MANAGER228/HMW3/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/MANAGER228/HMW3/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/MANAGER228/HMW3/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/MANAGER228/HMW3/contributors',
#   'created_at': '2020-05-27T07:19:01Z',
# ...

# %%
with open('json', 'w') as file:
    json.dump(data, file)

# %%
file = open('json', 'r')
print(file.read())
file.close()
# Out:
# [{"id": 267248816, "node_id": "MDEwOlJlcG9zaXRvcnkyNjcyNDg4MTY=", "name": "HMW3", "full_name": "MANAGER228/HMW3", "private": false, "owner": {"login": "MANAGER228", "id": 49758875, "node_id": "MDQ6VXNlcjQ5NzU4ODc1", "avatar_url": "https://avatars2.githubusercontent.com/u/49758875?v=4", "gravatar_id": "", "url": "https://api.github.com/users/MANAGER228", "html_url": "https://github.com/MANAGER228", "followers_url": "https://api.github.com/users/MANAGER228/followers", "following_url": "https://api.github.com/users/MANAGER228/following{/other_user}", "gists_url": "https://api.github.com/users/MANAGER228/gists{/gist_id}", "starred_url": "https://api.github.com/users/MANAGER228/starred{/owner}{/repo}", "subscriptions_url": "https://api.github.com/users/MANAGER228/subscriptions", "organizations_url": "https://api.github.com/users/MANAGER228/orgs", "repos_url": "https://api.github.com/users/MANAGER228/repos", "events_url": "https://api.github.com/users/MANAGER228/events{/privacy}", "receive
# ...

# %%
for line in data:
   print(line['name'])
# Out:
# HMW3
# HW3

# %%
#Задание 2

# %%
url_two = "https://heisenbug-premier-league-live-scores-v1.p.rapidapi.com/api/premierleague/table"

# %%
req_two = requests.get(f'{main_link}')

# %%
headers = {
    'x-rapidapi-host': "heisenbug-premier-league-live-scores-v1.p.rapidapi.com",
    'x-rapidapi-key': "a82e6702c1msh9846dbf63176026p1f04bbjsn78d1cd7f60f1"
    }

# %%
response = requests.request("GET", url_two, headers=headers)

# %%
res = response.json()

# %%
pprint(res)
# Out:
# {'records': [{'draw': 3,
#               'goalsAgainst': 32,
#               'goalsFor': 82,
#               'loss': 3,
#               'played': 37,
#               'points': 96,
#               'team': 'Liverpool',
#               'win': 31},
#              {'draw': 3,
#               'goalsAgainst': 35,
#               'goalsFor': 97,
#               'loss': 9,
#               'played': 37,
#               'points': 78,
#               'team': 'Manchester City',
#               'win': 25},
#              {'draw': 6,
#               'goalsAgainst': 54,
#               'goalsFor': 67,
#               'loss': 12,
#               'played': 37,
#               'points': 63,
#               'team': 'Chelsea',
#               'win': 19},
#              {'draw': 12,
#               'goalsAgainst': 36,
#               'goalsFor': 64,
#               'loss': 8,
#               'played': 37,
#               'points': 63,
#               'team': 'Manchester United',
# ...
